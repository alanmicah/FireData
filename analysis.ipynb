# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
wildfire_stats_filepath = '/Users/micah/build/FireData/input/FC-Wildfire-statistics-for-England-Report-to-2020-21-Supporting-Data.xlsx'
wildfire_stats_data = pd.read_excel(wildfire_stats_filepath, sheet_name='Dataset 1 Statistical regions', header=5)
wf = pd.DataFrame(wildfire_stats_data)
wildfire_stats_data.head()
# Out:
#           Region of England Region Code  Area (square kilometres)  \
# 0                North East   E12000001               8615.845994
# 1                North West   E12000002              14200.932325
# 2  Yorkshire and The Humber   E12000003              15485.866664
# 3             East Midlands   E12000004              15651.136481
# 4             West Midlands   E12000005              13003.737567
#
#    Wildfire incidents (number)  Area burnt (hectares)  \
# 0                        36920                    580
# 1                        55635                  45480
# 2                        51555                  10101
# 3                        30210                   1700
# 4                        45212                   1008
#
#    Duration of wildfire incidents (hours)
# 0                                   60030
# 1                                   60668
# 2                                   68554
# 3                                   51490
# ...

# %%
plt.figure(figsize=(18,10))
sns.barplot(x='Region of England', y='Wildfire incidents (number)', data=wf)
# Out:
# <Axes: xlabel='Region of England', ylabel='Wildfire incidents (number)'>

# %%
daily_fire_filepath = '/Users/micah/build/FireData/input/casualties-in-fires-dataset-270723.ods'
daily_fire_filepath = '/Users/micah/build/FireData/input/casualties-in-fires-dataset-270723.ods'
daily_fire_data = pd.read_excel(daily_fire_filepath, sheet_name='Datasheet')
daily_fire_data.head()
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x11012d010>>
# Traceback (most recent call last):
#   File "/Users/micah/mambaforge/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x11012d010>>
# Traceback (most recent call last):
#   File "/Users/micah/mambaforge/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(14,14))
sns.barplot(x=daily_fire_data['VICTIM_AGE'], y=daily_fire_data['VICTIM_GENDER'])
